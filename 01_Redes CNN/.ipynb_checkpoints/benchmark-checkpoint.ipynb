# %%
import tensorflow as tf
import numpy as np
import keras
from keras.datasets import cifar10
from keras.models import Sequential,Model
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Input
from keras import backend as K
from keras.callbacks import TensorBoard
from keras.optimizers import SGD,Adam
from keras.applications import vgg16,resnet50,inception_resnet_v2,inception_v3,xception
from keras_preprocessing import image
import matplotlib.pylab as plt

batch_size=100
num_classes=10
epochs=50


#from google.colab import drive
#drive.mount('/content/drive/')


modelos=["vgg16","InceptionV3","Resnet50","InceptionV4(Inception-ResnetV2)","Xception"]
respuestas=["container_ship","motor_scooter","leopard","mushroom","Madagascar_cat","dalmatian","marmot","tiger"]
for nim in range(1,10):
  im="drive/My Drive/imagenet/imagen_%d.png" % (nim)
  for Modelo in range(0,5):
    img = image.load_img(im, target_size=(224, 224, 3))
    imagen = image.img_to_array(img)
    imagen = np.expand_dims(imagen, axis=0)
    if(Modelo==0):
      from keras.applications.vgg16 import preprocess_input
      imagen = preprocess_input(imagen)
      modelo=vgg16.VGG16(weights='imagenet',include_top=True)
      #modelo.summary()
    if(Modelo==1):
      from keras.applications.inception_v3 import preprocess_input
      imagen = preprocess_input(imagen)
      modelo=inception_v3.InceptionV3(weights='imagenet',include_top=True)
      #modelo.summary()
    if(Modelo==2):
      from keras.applications.resnet50 import preprocess_input
      imagen = preprocess_input(imagen)
      modelo=resnet50.ResNet50(weights='imagenet',include_top=True)
      #modelo.summary()
    if(Modelo==3):
      from keras.applications.inception_resnet_v2 import preprocess_input
      imagen = preprocess_input(imagen)
      modelo=inception_resnet_v2.InceptionResNetV2(weights='imagenet',include_top=True)
      #modelo.summary()
    if(Modelo==4):
      from keras.applications.xception import preprocess_input
      imagen = preprocess_input(imagen)
      modelo=xception.Xception(weights='imagenet',include_top=True)
      #modelo.summary()



    prediccion=modelo.predict(imagen)

    from keras.applications.imagenet_utils import decode_predictions

    prediccion_decodificada=decode_predictions(prediccion)
    #prediccion_decodificada=np.array(prediccion_decodificada)
    print("La prediccion del modelo %s es %s con una probabilidad de %f" % (modelos[Modelo],prediccion_decodificada[0][0][1],prediccion_decodificada[0][0][2]*100))
  plt.figure(1)
  plt.imshow(image.img_to_array(img)/255)
  plt.show()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# La prediccion del modelo vgg16 es container_ship con una probabilidad de 97.206998
# La prediccion del modelo InceptionV3 es container_ship con una probabilidad de 93.813854
# La prediccion del modelo Resnet50 es container_ship con una probabilidad de 99.999702
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es container_ship con una probabilidad de 99.999976
# La prediccion del modelo Xception es snowplow con una probabilidad de 39.522240
# La prediccion del modelo vgg16 es motor_scooter con una probabilidad de 62.773770
# La prediccion del modelo InceptionV3 es motor_scooter con una probabilidad de 58.189768
# La prediccion del modelo Resnet50 es motor_scooter con una probabilidad de 85.092461
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es motor_scooter con una probabilidad de 78.937131
# La prediccion del modelo Xception es motor_scooter con una probabilidad de 78.445715
# La prediccion del modelo vgg16 es leopard con una probabilidad de 82.907194
# La prediccion del modelo InceptionV3 es leopard con una probabilidad de 86.776114
# La prediccion del modelo Resnet50 es leopard con una probabilidad de 61.489052
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es leopard con una probabilidad de 99.958783
# La prediccion del modelo Xception es leopard con una probabilidad de 97.789621
# La prediccion del modelo vgg16 es mushroom con una probabilidad de 80.918193
# La prediccion del modelo InceptionV3 es mushroom con una probabilidad de 99.756706
# La prediccion del modelo Resnet50 es mushroom con una probabilidad de 88.404411
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es mushroom con una probabilidad de 96.829188
# La prediccion del modelo Xception es mushroom con una probabilidad de 86.095065
# La prediccion del modelo vgg16 es indri con una probabilidad de 52.227521
# La prediccion del modelo InceptionV3 es gibbon con una probabilidad de 87.963754
# La prediccion del modelo Resnet50 es titi con una probabilidad de 42.377728
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es indri con una probabilidad de 98.571670
# La prediccion del modelo Xception es indri con una probabilidad de 79.078013
# La prediccion del modelo vgg16 es dalmatian con una probabilidad de 97.125071
# La prediccion del modelo InceptionV3 es dalmatian con una probabilidad de 99.999774
# La prediccion del modelo Resnet50 es dalmatian con una probabilidad de 99.762756
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es dalmatian con una probabilidad de 99.999654
# La prediccion del modelo Xception es dalmatian con una probabilidad de 99.979907
# La prediccion del modelo vgg16 es marmot con una probabilidad de 97.759694
# La prediccion del modelo InceptionV3 es marmot con una probabilidad de 99.999940
# La prediccion del modelo Resnet50 es meerkat con una probabilidad de 78.577614
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es marmot con una probabilidad de 99.999177
# La prediccion del modelo Xception es marmot con una probabilidad de 99.946958
# La prediccion del modelo vgg16 es tiger con una probabilidad de 93.598235
# La prediccion del modelo InceptionV3 es tiger con una probabilidad de 88.538343
# La prediccion del modelo Resnet50 es tiger con una probabilidad de 98.002714
# La prediccion del modelo InceptionV4(Inception-ResnetV2) es tiger con una probabilidad de 98.931670
